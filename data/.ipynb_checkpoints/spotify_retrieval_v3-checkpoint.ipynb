# %%
import datetime
import pandas as pd
import spotipy
import time
import json

from spotipy.oauth2 import SpotifyClientCredentials

CLIENT_ID = 'b64056860cea400eb01df73163d1201f'
CLIENT_SECRET = 'fefd5a3854eb4c3084b4f0f2a6846ede'

sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id=CLIENT_ID,
                                                           client_secret=CLIENT_SECRET))

# %%
# Step 1:  defines the list of artists (from Kaggle)

artist_list = [
    
                 "Coldplay",
                 "Radiohead",
                 "Red Hot Chili Peppers",
                 "Rihanna",
                 "Eminem",
                 "The Killers",
                 "Kanye West",
                 "Nirvana",
                 "Muse",
                 "Queen",
                 "Foo Fighters",
                 "Linkin Park",
                 "Lady Gaga",
                 "The Rolling Stones",
                 "Daft Punk",
                 "Green Day",
                 "Katy Perry",
                 "The Beatles",
                 "Oasis",
                 "Gorillaz",
                 "Beyonce",
                 "Michael Jackson",
                 "Maroon 5",
                 "Arctic Monkeys",
                 "System of a Down",
                 "U2",
                 "Kings of Leon",
                 "Drake",
                 "David Bowie",
                 "The Black Eyed Peas",
                 "The Strokes",
                 "Britney Spears",
                 "Guns N' Roses",
                 "Franz Ferdinand",
                 "The Doors",
                 "JAY-Z",
                 "Madonna",
                 "Pink Floyd",
                 "Weezer",
                 "Snow Patrol",
                 "blink 182",
                 "The White Stripes",
                 "The Cure",
                 "Led Zeppelin",
                 "Beck",
                 "Aerosmith",
                 "The Offspring",
                 "Metallica",
                 "R.E.M.",
                 "Blur",
                 "Adele",
                 "Rage Against the Machine",
                 "Death Cab for Cutie",
                 "Nickelback",
                 "Justin Timberlake",
                 "The Smashing Pumpkins",
                 "MGMT",
                 "Johnny Cash",
                 "Christina Aguilera",
                 "David Guetta",
                 "The Who",
                 "Jimi Hendrix",
                 "Fall Out Boy",
                 "Pearl Jam",
                 "AC/DC",
                 "Depeche Mode",
                 "Moby",
                 "Bob Dylan",
                 "Usher",
                 "50 Cent",
                 "The Kooks",
                 "Placebo",
                 "Avril Lavigne",
                 "Chris Brown",
                 "Christopher Brown",
                 "Incubus",
                 "Massive Attack",
                 "Arcade Fire",
                 "Korn",
                 "Jack Johnson",
                 "3 Doors Down",
                 "Amy Winehouse",
                 "Bloc Party",
                 "OutKast",
                 "Elton John",
                 "Yeah Yeah Yeahs",
                 "P!nk",
                 "Snoop Dogg",
                 "Kid Cudi",
                 "Kesha",
                 "Paramore",
                 "Queens of the Stone Age",
                 "Papa Roach",
                 "Mariah Carey",
                 "John Mayer",
                 "Black Sabbath",
                 "Kasabian",
                 "The Beach Boys",
                 "Kelly Clarkson",
                 "T.I.",
                 "Keane",
                 "Eric Clapton",
                 "Florence + the Machine",
                 "Modest Mouse",
                 "Elvis Presley",
                 "Disturbed",
                 "Simon & Garfunkel",
                 "Evanescence",
                 "My Chemical Romance",
                 "Creedence Clearwater Revival",
                 "Thirty Seconds to Mars",
                 "Frank Sinatra",
                 "Bon Jovi",
                 "Slipknot",
                 "Shakira",
                 "The Shins",
                 "The Clash",
                 "Dr. Dre",
                 "Alicia Keys",
                 "Pixies",
                 "Limp Bizkit",
                 "The Smiths",
                 "OneRepublic",
                 "The Cranberries",
                 "The Police",
                 "Kaiser Chiefs",
                 "Jason Mraz",
                 "Interpol",
                 "Beastie Boys",
                 "Nelly Furtado",
                 "Three Days Grace",
                 "The Chemical Brothers",
                 "Sum 41",
                 "Marilyn Manson",
                 "The Prodigy",
                 "The Fray",
                 "Audioslave",
                 "Taylor Swift",
                 "Panic! at the Disco",
                 "Calvin Harris",
                 "Wiz Khalifa",
                 "Bjork",
                 "2Pac",
                 "Vampire Weekend",
                 "Nine Inch Nails",
                 "John Lennon",
                 "Lily Allen",
                 "Bruce Springsteen",
                 "The Black Keys",
                 "Gwen Stefani",
                 "Air",
                 "Fleetwood Mac",
                 "Stevie Wonder",
                 "Dire Straits",
                 "Flo Rida",
                 "Sia",
                 "Deep Purple",
                 "Iron Maiden",
                 "The Kinks",
                 "Jennifer Lopez",
                 "Portishead",
                 "Jimmy Eat World",
                 "Goo Goo Dolls",
                 "Iron & Wine",
                 "Eagles",
                 "The Notorious B.I.G.",
                 "Norah Jones",
                 "The Verve",
                 "Nicki Minaj",
                 "The Pussycat Dolls",
                 "James Blunt",
                 "Rise Against",
                 "Phoenix",
                 "Miley Cyrus",
                 "The Game",
                 "Lupe Fiasco",
                 "No Doubt",
                 "Bob Marley",
                 "Akon",
                 "Pitbull",
                 "Breaking Benjamin",
                 "Bon Iver",
                 "The Velvet Underground",
                 "Joy Division",
                 "Feist",
                 "Leslie Feist",
                 "Counting Crows",
                 "Kylie Minogue",
                 "Sufjan Stevens",
                 "Nas",
                 "Alice in Chains",
                 "Ludacris",
                 "Fatboy Slim",
                 "Ellie Goulding",
                 "The xx",
                 "Lynyrd Skynyrd",
                 "Bob Marley & The Wailers",
                 "Marvin Gaye",
                 "Dido",
                 "Nelly",
                 "M83",
                 "Timbaland",
                 "Soundgarden",
                 "Lana Del Rey",
                 "Jason Derulo",
                 "Robbie Williams",
                 "Alanis Morissette",
                 "Bruno Mars",
                 "Cream",
                 "Bright Eyes",
                 "Ludwig van Beethoven",
                 "Regina Spektor",
                 "The Postal Service",
                 "Train",
                 "Phil Collins",
                 "M.I.A.",
                 "Ramones",
                 "Fergie",
                 "Michael Buble",
                 "New Order",
                 "Rammstein",
                 "Mumford & Sons",
                 "Destiny's Child",
                 "Lenny Kravitz",
                 "Good Charlotte",
                 "Nina Simone",
                 "Bullet for My Valentine",
                 "Sting",
                 "Van Halen",
                 "Hoobastank",
                 "Ozzy Osbourne",
                 "Billy Joel",
                 "Bryan Adams",
                 "Damien Rice",
                 "Neil Young",
                 "Jet",
                 "Aretha Franklin",
                 "John Legend",
                 "Foster the People",
                 "Sublime",
                 "Deftones",
                 "Band of Horses",
                 "The Flaming Lips",
                 "The National",
                 "Louis Armstrong",
                 "Prince",
                 "Rick Ross",
                 "Tenacious D",
                 "Avenged Sevenfold",
                 "Two Door Cinema Club",
                 "Blondie",
                 "Journey",
                 "Justice",
                 "Goldfrapp",
                 "Belle and Sebastian",
                 "Travis",
                 "Ciara",
                 "Ray Charles",
                 "The Cardigans",
                 "The Script",
                 "Passion Pit",
                 "Leona Lewis",
                 "Elliott Smith",
                 "Simple Plan",
                 "Paul McCartney",
                 "Imagine Dragons",
                 "Editors",
                 "ABBA",
                 "Van Morrison",
                 "Scorpions",
                 "MIKA",
                 "Cat Power",
                 "Jamiroquai",
                 "CAKE",
                 "Justin Bieber",
                 "Ella Fitzgerald",
                 "Fleet Foxes",
                 "Ed Sheeran",
                 "LCD Soundsystem",
                 "KISS",
                 "Sonic Youth",
                 "Talking Heads",
                 "Stereophonics",
                 "Seether",
                 "Gnarls Barkley",
                 "Whitney Houston",
                 "Jeff Buckley",
                 "Aha",
                 "Duran Duran",
                 "A Perfect Circle",
                 "The Jimi Hendrix Experience",
                 "James Brown",
                 "Garbage",
                 "Wolfgang Amadeus Mozart",
                 "Lifehouse",
                 "Lykke Li",
                 "Santana",
                 "J. Cole",
                 "Tool",
                 "Tyga",
                 "Young Jeezy",
                 "B.o.B",
                 "Pantera",
                 "Bloodhound Gang",
                 "Jefferson Airplane",
                 "Avicii",
                 "Enrique Iglesias",
                 "Stone Temple Pilots",
                 "The Fratellis",
                 "Spoon",
                 "deadmau5",
                 "Stone Sour",
                 "Johann Sebastian Bach",
                 "Lou Reed",
                 "Crystal Castles",
                 "Aphex Twin",
                 "Ice Cube",
                 "Skrillex",
                 "Miles Davis",
                 "The Decemberists",
                 "Staind",
                 "Taio Cruz",
                 "Iggy Pop",
                 "Fabolous",
                 "The Jackson 5",
                 "Wolfmother",
                 "Metric",
                 "EELS",
                 "Nat King Cole",
                 "Bonobo",
                 "George Michael",
                 "Yellowcard",
                 "Cyndi Lauper",
                 "Godsmack",
                 "Electric Light Orchestra",
                 "The Hives",
                 "Tears for Fears",
                 "Eurythmics",
                 "Kendrick Lamar",
                 "Cypress Hill",
                 "Hot Chip",
                 "The Ting Tings",
                 "PJ Harvey",
                 "R. Kelly",
                 "Thievery Corporation",
                 "Foals",
                 "Zero 7",
                 "Tom Waits",
                 "DMX",
                 "Razorlight",
                 "Broken Social Scene",
                 "Jessie J",
                 "James Morrison",
                 "Big Sean",
                 "Bee Gees",
                 "Chuck Berry",
                 "Toto",
                 "Hans Zimmer",
                 "Imogen Heap",
                 "ZZ Top",
                 "Nick Drake",
                 "Colbie Caillat",
                 "Otis Redding",
                 "Backstreet Boys",
                 "Megadeth",
                 "Wale",
                 "Leonard Cohen",
                 "Janis Joplin",
                 "Natasha Bedingfield",
                 "TV on the Radio",
                 "Owl City",
                 "Sarah McLachlan",
                 "Klaxons",
                 "Groove Armada",
                 "The Roots",
                 "Creed",
                 "Sean Paul",
                 "Duffy",
                 "Billy Talent",
                 "Trey Songz",
                 "Sara Bareilles",
                 "Grizzly Bear",
                 "Celine Dion",
                 "Matchbox Twenty",
                 "Dave Matthews Band",
                 "Faithless",
                 "Alice Cooper",
                 "P.O.D.",
                 "Slayer",
                 "N*E*R*D",
                 "Fiona Apple",
                 "Beirut",
                 "Gotye",
                 "Yann Tiersen",
                 "Nightwish",
                 "Lostprophets",
                 "Judas Priest",
                 "Busta Rhymes",
                 "Kings of Convenience",
                 "Cold War Kids",
                 "Pendulum",
                 "Rod Stewart",
                 "Drowning Pool",
                 "The Knife",
                 "La Roux",
                 "Common",
                 "The Libertines",
                 "The Animals",
                 "Paul Simon",
                 "Ben Harper",
                 "Tegan and Sara",
                 "Boards of Canada",
                 "A Tribe Called Quest",
                 "Wilco",
                 "Enya",
                 "Cat Stevens",
                 "Empire of the Sun",
                 "Genesis",
                 "AFI",
                 "Mary J. Blige",
                 "Mogwai",
                 "KT Tunstall",
                 "Foreigner",
                 "Al Green",
                 "Animal Collective",
                 "George Harrison",
                 "DJ Shadow",
                 "Demi Lovato",
                 "Nick Cave & The Bad Seeds",
                 "Tori Amos",
                 "Boston",
                 "Janet Jackson",
                 "Kelis",
                 "Morcheeba",
                 "Neutral Milk Hotel",
                 "Hall & Oates",
                 "The Weeknd",
                 "Dean Martin",
                 "LMFAO",
                 "Gucci Mane",
                 "Rob Zombie",
                 "OK Go",
                 "The Raconteurs",
                 "The Temptations",
                 "Sade",
                 "Sheryl Crow",
                 "Taking Back Sunday",
                 "Lorde",
                 "Robyn",
                 "Pharrell Williams",
                 "Billy Idol",
                 "Black Rebel Motorcycle Club",
                 "Faith No More",
                 "fun.",
                 "The Used",
                 "Of Monsters and Men",
                 "The Temper Trap",
                 "Fryderyk Chopin",
                 "Fort Minor",
                 "Peter Bjorn and John",
                 "Spice Girls",
                 "We Are Scientists",
                 "Sean Kingston",
                 "Scissor Sisters",
                 "Major Lazer",
                 "Brand New",
                 "All Time Low",
                 "Wham!",
                 "Kate Nash",
                 "MARINA",
                 "Morrissey",
                 "Cage the Elephant",
                 "Pet Shop Boys",
                 "Gym Class Heroes",
                 "Bill Withers",
                 "Fugees",
                 "Apocalyptica",
                 "Missy Elliott",
                 "Supertramp",
                 "Skillet",
                 "D12",
                 "Dashboard Confessional",
                 "Smash Mouth",
                 "Bush",
                 "Andrew Bird",
                 "Beach House",
                 "A Day to Remember",
                 "Killswitch Engage",
                 "Frank Ocean",
                 "Billie Holiday",
                 "John Williams",
                 "Mark Ronson",
                 "Ryan Adams",
                 "Explosions in the Sky",
                 "Earth,Earth",
                 "Keri Hilson",
                 "Natalie Imbruglia",
                 "In Flames",
                 "Corinne Bailey Rae",
                 "The Wombats",
                 "The Stone Roses",
                 "Swedish House Mafia",
                 "Basement Jaxx",
                 "Daughtry",
                 "The Dandy Warhols",
                 "Bat for Lashes",
                 "Third Eye Blind",
                 "TLC",
                 "Kansas",
                 "The Bravery",
                 "Tom Petty and the Heartbreakers",
                 "Sex Pistols",
                 "Shinedown",
                 "White Lies",
                 "DJ Khaled",
                 "Kate Bush",
                 "Miike Snow",
                 "INXS",
                 "Cut Copy",
                 "Peter Gabriel",
                 "Edward Sharpe and the Magnetic Zeros",
                 "Static-X",
                 "Benny Benassi",
                 "Roxette",
                 "Pulp",
                 "The Byrds",
                 "David Gray",
                 "Kelly Rowland",
                 "Young Money",
                 "The Cinematic Orchestra",
                 "Ray LaMontagne",
                 "Tracy Chapman",
                 "The Kills",
                 "will.i.am",
                 "Puddle of Mudd",
                 "Bombay Bicycle Club",
                 "Whitesnake",
                 "Robin Thicke",
                 "Antonio Vivaldi",
                 "Manu Chao",
                 "Bad Religion",
                 "Tame Impala",
                 "The Mamas & the Papas",
                 "Rush",
                 "Paolo Nutini",
                 "Joe Cocker",
                 "Gavin DeGraw",
                 "Brian Eno",
                 "Ennio Morricone",
                 "Macklemore & Ryan Lewis",
                 "Steppenwolf",
                 "of Montreal",
                 "Stars",
                 "Armin van Buuren",
                 "Cher",
                 "Simple Minds",
                 "The Lumineers",
                 "Yes",
                 "Sugababes",
                 "Def Leppard",
                 "UNKLE",
                 "Alien Ant Farm",
                 "Santigold",
                 "Mudvayne",
                 "Ariana Grande",
                 "Diana Krall",
                 "Yo La Tengo",
                 "Tricky",
                 "alt-J",
                 "Etta James",
                 "Dusty Springfield",
                 "Aaliyah",
                 "Chevelle",
                 "Mike Posner",
                 "Soulja Boy Tell Em",
                 "Seal",
                 "Lamb",
                 "New Found Glory",
                 "The Allman Brothers Band",
                 "Bring Me the Horizon",
                 "Rufus Wainwright",
                 "NOFX",
                 "Tom Petty",
                 "Carly Rae Jepsen",
                 "Birdman",
                 "Manic Street Preachers",
                 "Mos Def",
                 "Cascada",
                 "Underworld",
                 "Supergrass",
                 "Europe",
                 "Jethro Tull",
                 "Survivor",
                 "Bastille",
                 "Doves",
                 "Angus & Julia Stone",
                 "One Direction",
                 "Kool & The Gang",
                 "The Mars Volta",
                 "Roy Orbison",
                 "Erykah Badu",
                 "Jamie Cullum",
                 "HIM",
                 "Within Temptation",
                 "Laura Marling",
                 "Moloko",
                 "T. Rex",
                 "Joss Stone",
                 "N.W.A",
                 "John Coltrane",
                 "Mario",
                 "Heart",
                 "Mac Miller",
                 "Ingrid Michaelson",
                 "Devendra Banhart",
                 "Pavement",
                 "Dropkick Murphys",
                 "Glee Cast",
                 "Atreyu",
                 "Steve Miller Band",
                 "Bing Crosby",
                 "Elbow",
                 "Carrie Underwood",
                 "311",
                 "Digitalism",
                 "Noah and the Whale",
                 "The Yardbirds",
                 "Dream Theater",
                 "Lionel Richie",
                 "Joni Mitchell",
                 "Thom Yorke",
                 "RJD2",
                 "Boys Like Girls",
                 "Barenaked Ladies",
                 "Enigma",
                 "Flyleaf",
                 "Echo & The Bunnymen",
                 "Nancy Sinatra",
                 "Sinead O'Connor",
                 "Birdy",
                 "Zedd",
                 "Five Finger Death Punch",
                 "Primal Scream",
                 "Trivium",
                 "Chicago",
                 "Lamb of God",
                 "James Blake",
                 "Hooverphonic",
                 "Broken Bells",
                 "Rilo Kiley",
                 "Ladytron",
                 "Sam Cooke",
                 "The Stooges",
                 "Janet's Addiction",
                 "Trapt",
                 "My Morning Jacket",
                 "Hinder",
                 "Joshua Radin",
                 "Shaggy",
                 "Selena Gomez & The Scene",
                 "Nouvelle Vague",
                 "Disclosure",
                 "Jay Sean",
                 "Tina Turner",
                 "Nicole Scherzinger",
                 "Lauryn Hill",
                 "Selena Gomez",
                 "Lady Antebellum",
                 "Elvis Costello",
                 "Frou Frou",
                 "Far East Movement",
                 "City and Colour",
                 "AWOLNATION",
                 "Willie Nelson",
                 "Guano Apes",
                 "Eddie Vedder",
                 "Clap Your Hands Say Yeah",
    
]

# %%
results = sp.search(q=f'artist:Clap Your Hands Say Yeah', type='artist', limit=1)
print(json.dumps(results, indent=2))
# Out:
# {
#   "artists": {
#     "href": "https://api.spotify.com/v1/search?query=artist%3AClap+Your+Hands+Say+Yeah&type=artist&offset=0&limit=1",
#     "items": [
#       {
#         "external_urls": {
#           "spotify": "https://open.spotify.com/artist/1jSaZgaKHmgc7VTgML528r"
#         },
#         "followers": {
#           "href": null,
#           "total": 170014
#         },
#         "genres": [
#           "alternative dance",
#           "alternative rock",
#           "brooklyn indie",
#           "chamber pop",
#           "indie pop",
#           "indie rock",
#           "modern rock",
#           "new rave",
#           "philly indie",
#           "stomp and holler"
#         ],
#         "href": "https://api.spotify.com/v1/artists/1jSaZgaKHmgc7VTgML528r",
#         "id": "1jSaZgaKHmgc7VTgML528r",
#         "images": [
#           {
#             "height": 640,
#             "url": "https://i.scdn.co/image/ab6761610000e5eb431a75b6e3131eaea120effe",
# ...

# %%
# Step 2:  using a list of artists from the Kaggle dataset, 
#          gets each individual artist's Spotify ID (which will be used for iteration later)

start_time = time.process_time()
artist_id = []
error = []

count = 0
for artist in artist_list:
    results = sp.search(q=f'artist:{artist}', type='artist', limit=1)
    count += 1
    
    if count % 50 == 0:
        print("Completed API Call:", count)
        print("Elapsed time:", time.process_time() - start_time)
    try:
        artist_id.append(
            {
                'Artist_ID': results['artists']['items'][0]['id'],
                'Artist': results['artists']['items'][0]['name']
            }
        )
    except Exception as e:
        print("Error on record index:", count - 1 )
        error.append((e, results))
    
'''
[VT] - Looping through all tracks and appending artist ID and name. We can do a bit better by specifying
search to specifically pull artist info and limit results to 1, removing inner loop
With this, it takes about 0.4 seconds for every 50 API calls
'''
#     for idx, track in enumerate(results['tracks']['items']):
#         artist_id.append (
#             {
#                 'Artist_ID' : track['artists'][0]['id'],
#                 'Artist' : track['artists'][0]['name']
#             }
#         )

end_time = time.process_time()
df = pd.DataFrame(artist_id)

print("Elapsed Time:", (end_time - start_time))
df.head(20)
# Out:
# Completed API Call: 50
# Elapsed time: 0.43625899999999973
# Completed API Call: 100
# Elapsed time: 0.8585810000000009
# Completed API Call: 150
# Elapsed time: 1.2866959999999992
# Completed API Call: 200
# Elapsed time: 1.7080210000000022
# Completed API Call: 250
# Elapsed time: 2.1346990000000012
# Completed API Call: 300
# Elapsed time: 2.5609610000000025
# Completed API Call: 350
# Elapsed time: 2.9872250000000022
# Error on record index: 395
# Completed API Call: 400
# Elapsed time: 3.414446999999999
# Completed API Call: 450
# Elapsed time: 3.8357969999999995
# Completed API Call: 500
# Elapsed time: 4.261419
# Completed API Call: 550
# Elapsed time: 4.677076
# Completed API Call: 600
# Elapsed time: 5.1059540000000005
# Completed API Call: 650
# Elapsed time: 5.510711000000001
# Error on record index: 653
# Elapsed Time: 5.7474430000000005
#                  Artist_ID                 Artist
# 0   4gzpq5DPGxSnKTe4SA8HAU               Coldplay
# ...

# %%
print(len(df))
# Out:
# 675

# %%
df.head(3)
# Out:
#                 Artist_ID                 Artist
# 0  4gzpq5DPGxSnKTe4SA8HAU               Coldplay
# 1  4Z8W4fKeB5YxbusRsdQVPb              Radiohead
# 2  0L8ExT028jH3ddEcZwqJJ5  Red Hot Chili Peppers

# %%
# Step 3:  creates a list of artist IDs (used in Step 4)
artist_id_list = df['Artist_ID'].tolist()

# %%
results = sp.artist_albums(artist_id, album_type='album', limit=1)
print(json.dumps(results, indent=2))
# Out:
# {
#   "href": "https://api.spotify.com/v1/artists/4gzpq5DPGxSnKTe4SA8HAU/albums?offset=0&limit=1&include_groups=album",
#   "items": [
#     {
#       "album_group": "album",
#       "album_type": "album",
#       "artists": [
#         {
#           "external_urls": {
#             "spotify": "https://open.spotify.com/artist/4gzpq5DPGxSnKTe4SA8HAU"
#           },
#           "href": "https://api.spotify.com/v1/artists/4gzpq5DPGxSnKTe4SA8HAU",
#           "id": "4gzpq5DPGxSnKTe4SA8HAU",
#           "name": "Coldplay",
#           "type": "artist",
#           "uri": "spotify:artist:4gzpq5DPGxSnKTe4SA8HAU"
#         }
#       ],
#       "available_markets": [
#         "AR",
#         "AU",
#         "AT",
#         "BE",
#         "BO",
#         "BR",
#         "BG",
#         "CA",
#         "CL",
#         "CO",
#         "CR",
#         "CY",
#         "CZ",
#         "DK",
#         "DO",
#         "DE",
#         "EC",
#         "EE",
#         "SV",
#         "FI",
# ...

# %%
# How many albums does each artist have?
album_count = []
album_error = []

for artist_id in artist_id_list:
    results = sp.artist_albums(artist_id, album_type='album', limit=1)
    try:
        album_count.append((results['items'][0]['artists'][0]['name'], results['total']))
    except Exception as e:
        print("Found error")
        album_error.append((e, results))
        

df_album_count = pd.DataFrame(album_count, col)
df_album_count.columns = ['Artist Name', 'Count Albums']
df_album_count.head()
# Out:
# Found error
# Found error
# Found error
# Found error
# Found error
# Found error
# Found error
#                        0   1
# 0               Coldplay  30
# 1              Radiohead  14
# 2  Red Hot Chili Peppers  19
# 3                Rihanna  46
# 4                 Eminem  48

# %%
print(df_album_count['Count Albums'].mean())
print(df_album_count['Count Albums'].max())
print(df_album_count['Count Albums'].min())
ax = df_album_count[df_album_count['Count Albums'] > 50].sort_values('Count Albums').plot.bar(x='Artist Name', y='Count Albums', rot=0)
print(len(df_album_count[df_album_count['Count Albums'] > 50]))
# Out:
# 34.68862275449102
# 931
# 1
# 82

# %%
df_album_count[df_album_count['Count Albums'] == 931]
# Out:
#               Artist Name  Count Albums
# 208  Ludwig van Beethoven           931

# %%
df[df["Artist_ID"] == '6RKo2uCyTZTeUlfOgrxivx']
# Out:
#                  Artist_ID               Artist
# 29  6RKo2uCyTZTeUlfOgrxivx  The Black Eyed Peas

# %%
# Step 4:  using the artist IDs from step 3, gets all the albums for each artist
'''
[VT] We can reduce the number of API calls by setting limit = 50 so we don't need
to iterate to the next block of albums
'''
start_time = time.process_time()
albums = []
count = 0

for artist_id in artist_id_list:
    results = sp.artist_albums(artist_id, album_type='album', limit = 50)
    count += 1
    
    if count % 50 == 0:
        print("Completed Album API Call:", count)
        print("Elapsed time:", time.process_time() - start_time)
    
    albums.extend(results['items'])

end_time = time.process_time()

elapsed_time = end_time - start_time
elapsed_time
# Out:
# Completed Album API Call: 50
# Elapsed time: 0.5409149999999983
# Completed Album API Call: 100
# Elapsed time: 0.9851329999999976
# Completed Album API Call: 150
# Elapsed time: 1.4994379999999978
# Completed Album API Call: 200
# Elapsed time: 1.9494100000000003
# Completed Album API Call: 250
# Elapsed time: 2.4606270000000023
# Completed Album API Call: 300
# Elapsed time: 3.0583489999999998
# Completed Album API Call: 350
# Elapsed time: 3.5566069999999996
# Completed Album API Call: 400
# Elapsed time: 4.058533000000004
# Completed Album API Call: 450
# Elapsed time: 4.567644999999999
# Completed Album API Call: 500
# Elapsed time: 5.059430000000006
# Completed Album API Call: 550
# Elapsed time: 5.5636030000000005
# Completed Album API Call: 600
# Elapsed time: 6.056368000000006
# Completed Album API Call: 650
# Elapsed time: 6.585713999999996
# 6.849132999999995

# %%
# Step 5:  using the 'albums' object from Step #4, builds a clean dataframe of albums for each artist
#          (includes the associated album ID, which is used in Step #6)

start_time = datetime.datetime.now()
album_list = []

for idx, album in enumerate(albums):
    try:
        album_list.append (
            {
                'Artist_ID' : album['artists'][0]['id'],
                'Artist_Name' : album['artists'][0]['name'],
                'Album_ID' : album['id'],
                'Album_Name' : album['name'],
                'Total_Tracks' : album['total_tracks'],
                'Release_Date' : album['release_date'],            
                'Spotify_URL' : album['external_urls']['spotify'],
                'Album_Image' : album['images'][1]['url']
            }
        )
    
    except IndexError:

        album_list.append (
            {
                'Artist_ID' : album['artists'][0]['id'],
                'Artist_Name' : album['artists'][0]['name'],
                'Album_ID' : album['id'],
                'Album_Name' : album['name'],
                'Total_Tracks' : album['total_tracks'],
                'Release_Date' : album['release_date'],            
                'Spotify_URL' : album['external_urls']['spotify'],
                'Album_Image' : ''
            }
        )
    

df_albums = pd.DataFrame(album_list)
end_time = datetime.datetime.now()

elapsed_time = end_time - start_time
elapsed_time
# Out:
# datetime.timedelta(microseconds=91211)

# %%
df_albums.head(3)
# Out:
#                 Artist_ID Artist_Name                Album_ID  \
# 0  4gzpq5DPGxSnKTe4SA8HAU    Coldplay  06mXfvDsRZNfnsGZvX2zpb
# 1  4gzpq5DPGxSnKTe4SA8HAU    Coldplay  7z0efuBXAnPfu60aOL3QFV
# 2  4gzpq5DPGxSnKTe4SA8HAU    Coldplay  2FeyIYDDAQqcOJKOKhvHdr
#
#              Album_Name  Total_Tracks Release_Date  \
# 0  Music Of The Spheres            12   2021-10-15
# 1         Everyday Life            17   2019-11-22
# 2         Everyday Life            16   2019-11-22
#
#                                          Spotify_URL  \
# 0  https://open.spotify.com/album/06mXfvDsRZNfnsG...
# 1  https://open.spotify.com/album/7z0efuBXAnPfu60...
# 2  https://open.spotify.com/album/2FeyIYDDAQqcOJK...
#
#                                          Album_Image
# 0  https://i.scdn.co/image/ab67616d00001e02ec10f2...
# 1  https://i.scdn.co/image/ab67616d00001e020fc77f...
# 2  https://i.scdn.co/image/ab67616d00001e02733913...

# %%
# Step 6:  using the data from Step #5, creates a list of album IDs for all artists
album_id_list = df_albums['Album_ID'].tolist()

# %%
results = sp.album_tracks(album_id)
print(json.dumps(results, indent=2))
# Out:
# {
#   "href": "https://api.spotify.com/v1/albums/1dFU0o5VMR7R0W1FkRnmHm/tracks?offset=0&limit=50",
#   "items": [
#     {
#       "artists": [
#         {
#           "external_urls": {
#             "spotify": "https://open.spotify.com/artist/0L8ExT028jH3ddEcZwqJJ5"
#           },
#           "href": "https://api.spotify.com/v1/artists/0L8ExT028jH3ddEcZwqJJ5",
#           "id": "0L8ExT028jH3ddEcZwqJJ5",
#           "name": "Red Hot Chili Peppers",
#           "type": "artist",
#           "uri": "spotify:artist:0L8ExT028jH3ddEcZwqJJ5"
#         }
#       ],
#       "available_markets": [
#         "JP"
#       ],
#       "disc_number": 1,
#       "duration_ms": 101120,
#       "explicit": false,
#       "external_urls": {
#         "spotify": "https://open.spotify.com/track/32IMbUD0ddD96V7lLCZwa0"
#       },
#       "href": "https://api.spotify.com/v1/tracks/32IMbUD0ddD96V7lLCZwa0",
#       "id": "32IMbUD0ddD96V7lLCZwa0",
#       "is_local": false,
# ...

# %%
# How many tracks does each album have?
track_count = []
track_error = []
count = 0

for album_id in album_id_list:
    results = results = sp.album_tracks(album_id, limit=50)
    count += 1
    if count % 50 == 0:
        print("Completed Album API Call:", count)
        print("Elapsed time:", time.process_time() - start_time)
        
    try:
        track_count.append(results['total'])
    except Exception as e:
        print("Found error")
        track_error.append((e, results))
        

df_series_tracks = pd.Series(track_count)
# Out:
# Completed Album API Call: 50
# Elapsed time: 1.1145340000000061
# Completed Album API Call: 100
# Elapsed time: 1.576870999999997
# Completed Album API Call: 150
# Elapsed time: 2.0563410000000033
# Completed Album API Call: 200
# Elapsed time: 2.5228409999999997
# Completed Album API Call: 250
# Elapsed time: 3.009875000000008
# Completed Album API Call: 300
# Elapsed time: 3.472957000000008
# Completed Album API Call: 350
# Elapsed time: 3.9294399999999996
# Completed Album API Call: 400
# Elapsed time: 4.3915640000000025
# Completed Album API Call: 450
# Elapsed time: 4.847504000000001
# Completed Album API Call: 500
# Elapsed time: 5.30520700000001
# Completed Album API Call: 550
# Elapsed time: 5.748159999999999
# Completed Album API Call: 600
# Elapsed time: 6.199612000000002
# Completed Album API Call: 650
# Elapsed time: 6.661757000000009
# Completed Album API Call: 700
# Elapsed time: 7.101022
# Completed Album API Call: 750
# Elapsed time: 7.546003999999996
# ...

# %%
df_series_tracks = pd.Series(track_count)
print(df_series_tracks.mean())
print(df_series_tracks.min())
print(df_series_tracks.max())
df_series_tracks.sort_values().plot.bar()
# Out:
# 17.371951219512194
# 1
# 107

# %%
# Step 7:  using the list of album IDs from Step #6, gets all of the tracks on a given album

start_time = time.process_time()
tracks = []
count = 0

for album_id in album_id_list:

    results = sp.album_tracks(album_id, limit=50)
    count += 1
    
    if count % 50 == 0:
        print("Completed Album API Call:", count)
        print("Elapsed time:", time.process_time() - start_time)
    
    tracks.extend(results['items'])
    seen = set()  # to avoid duplicates
    tracks.sort(key=lambda album: album['name'].lower())
    for album in tracks:
        name = album['name']
        if name not in seen:
            seen.add(name)

end_time = time.process_time()

elapsed_time = end_time - start_time
elapsed_time
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-65-727f0c2f54b1> in <module>
#       6 for album_id in album_id_list:
#       7
# ----> 8     results = sp.album_tracks(album_id)
#       9     tracks.extend(results['items'])
#      10     while results['next']:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/spotipy/client.py in album_tracks(self, album_id, limit, offset, market)
#     472         trid = self._get_id("album", album_id)
#     473         return self._get(
# --> 474             "albums/" + trid + "/tracks/", limit=limit, offset=offset, market=market
#     475         )
#     476
#
# ~/opt/anaconda3/lib/python3.7/site-packages/spotipy/client.py in _get(self, url, args, payload, **kwargs)
#     319             kwargs.update(args)
#     320
# --> 321         return self._internal_call("GET", url, payload, kwargs)
#     322
# ...
