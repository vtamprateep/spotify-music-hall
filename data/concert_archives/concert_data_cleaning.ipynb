# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("artist_concert_data.csv")
clean_df = df.copy()
df.head()
# Out:
#         Date                                            Concert  \
# 0  26-Nov-22                                          Faithless
# 1  24-Sep-22        Faithless / Crazy P / Don Letts / Dat Brass
# 2  15-Sep-22                                          faithless
# 3  21-Aug-22  Camp Bestival "Camp Bestival" / Rag N Bone Man...
# 4  29-Jul-22  Camp Bestival "Camp Bestival" / Rag N Bone Man...
#
#                    Venue                           Location Unnamed: 4  \
# 0             Concorde 2  Brighton, England, United Kingdom        NaN
# 1      Dreamland Margate            Margate, United Kingdom        NaN
# 2  Sportpaleis Antwerpen         Antwerp, Flanders, Belgium        NaN
# 3            Weston Park                  Staffordshire, UK        NaN
# 4        Lulworth Castle             Dorset, United Kingdom        NaN
#
#       Artist
# 0  Faithless
# 1  Faithless
# 2  Faithless
# 3  Faithless
# 4  Faithless

# %%
# Remove bad dates from 'Date' column - Show Duplicate, Upcoming, Rescheduled, Cancelled
mask = clean_df["Date"].str.contains("(Show Duplicate|Upcoming|Rescheduled|Cancelled|No concerts found)")
clean_df = clean_df[~mask]

clean_df.head()
# Out:
# /var/folders/d3/k0v5vst508sc7glyv2sbz9880000gn/T/ipykernel_3446/533788223.py:2: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   mask = clean_df["Date"].str.contains("(Show Duplicate|Upcoming|Rescheduled|Cancelled|No concerts found)")
#         Date                                            Concert  \
# 0  26-Nov-22                                          Faithless
# 1  24-Sep-22        Faithless / Crazy P / Don Letts / Dat Brass
# 2  15-Sep-22                                          faithless
# 3  21-Aug-22  Camp Bestival "Camp Bestival" / Rag N Bone Man...
# 4  29-Jul-22  Camp Bestival "Camp Bestival" / Rag N Bone Man...
#
#                    Venue                           Location Unnamed: 4  \
# 0             Concorde 2  Brighton, England, United Kingdom        NaN
# 1      Dreamland Margate            Margate, United Kingdom        NaN
# 2  Sportpaleis Antwerpen         Antwerp, Flanders, Belgium        NaN
# 3            Weston Park                  Staffordshire, UK        NaN
# 4        Lulworth Castle             Dorset, United Kingdom        NaN
#
#       Artist
# 0  Faithless
# 1  Faithless
# 2  Faithless
# 3  Faithless
# 4  Faithless

# %%
# Format dates not in the format DD-MMM-YY
test_date_regex = "^\d{1,2}-[a-zA-Z]{3}-\d{1,2}"
date_format_mask = clean_df["Date"].str.match(test_date_regex)

# Grab dates that are in range, split, select earliest date
unformatted_date_df = clean_df[~date_format_mask]["Date"]
unformatted_date_df = unformatted_date_df.str.split("–", expand=True)[0]
unformatted_date_df

# Replace based on indices
clean_df["Date"].loc[unformatted_date_df.index] = unformatted_date_df

# Format MMM DD, YYYY to DD-MM-YY
clean_df["Date"] = clean_df["Date"].astype("datetime64[ns]")
clean_df
# Out:
#              Date                                            Concert  \
# 0      2022-11-26                                          Faithless
# 1      2022-09-24        Faithless / Crazy P / Don Letts / Dat Brass
# 2      2022-09-15                                          faithless
# 3      2022-08-21  Camp Bestival "Camp Bestival" / Rag N Bone Man...
# 4      2022-07-29  Camp Bestival "Camp Bestival" / Rag N Bone Man...
# ...           ...                                                ...
# 200733 2022-06-06                       Dave Matthews Band  Setlists
# 200734 2022-06-06                                 Dave Matthews Band
# 200735 2022-06-04                       Dave Matthews Band  Setlists
# 200736 2022-06-03                       Dave Matthews Band  Setlists
# 200737 2022-06-03                       Dave Matthews Band  Setlists
#
#                         Venue                                   Location  \
# 0                  Concorde 2          Brighton, England, United Kingdom
# 1           Dreamland Margate                    Margate, United Kingdom
# 2       Sportpaleis Antwerpen                 Antwerp, Flanders, Belgium
# 3                 Weston Park                          Staffordshire, UK
# 4             Lulworth Castle                     Dorset, United Kingdom
# ...                       ...                                        ...
# 200733          Daily's Place       Jacksonville, Florida, United States
# 200734   Blossom Music Center                     Cuyahoga Falls, OH, US
# 200735     Credit One Stadium                                        NaN
# 200736     Credit One Stadium  Charleston, South Carolina, United States
# 200737     Credit One Stadium                                        NaN
#
#        Unnamed: 4              Artist
# 0             NaN           Faithless
# 1             NaN           Faithless
# 2             NaN           Faithless
# 3             NaN           Faithless
# 4             NaN           Faithless
# ...           ...                 ...
# 200733        NaN  Dave Matthews Band
# 200734        NaN  Dave Matthews Band
# 200735        NaN  Dave Matthews Band
# 200736        NaN  Dave Matthews Band
# 200737        NaN  Dave Matthews Band
#
# [159280 rows x 6 columns]

# %%
# Remove unknown venue
na_venue_mask = clean_df["Venue"].isna()
clean_df = clean_df[~na_venue_mask]

# Get venue names where location unknown
na_location_mask = clean_df["Location"].isna()
venue_name = set(clean_df[na_location_mask]["Venue"])

venue_filter_mask = clean_df["Venue"].isin(venue_name)
venue_loc_infer = clean_df[~na_location_mask & venue_filter_mask][["Venue", "Location"]]

# %%
# Rank venue location map and get the first value
resolved_venue_loc = venue_loc_infer.groupby("Venue").nth(0)
type(resolved_venue_loc)

# Map function to replace NA
def remove_loc_na(row):
    if not pd.isnull(row["Location"]):
        return row["Location"]
    if pd.isnull(row["Location"]) and row["Venue"] in set(resolved_venue_loc.index):
        return resolved_venue_loc.loc[row["Venue"]]
    else:
        return np.nan
        
# Loop through DF and resolve missing locations
clean_df["Location"] = clean_df.apply(remove_loc_na, axis = 1)
clean_df[na_location_mask]
# Out:
# /var/folders/d3/k0v5vst508sc7glyv2sbz9880000gn/T/ipykernel_3446/617924354.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   clean_df["Location"] = clean_df.apply(remove_loc_na, axis = 1)
#              Date                                            Concert  \
# 227    2022-10-07                             Alice Cooper  Setlists
# 240    2022-09-20                     Alice Cooper  Photos  Setlists
# 540    2019-08-06                                             P.O.D.
# 1269   2012-10-05                    Gotye / Missy Higgins  Setlists
# 1505   2023-01-30  70000 Tons of Metal Hei'An / Vicious Rumors / ...
# ...           ...                                                ...
# 200210 2017-12-01                     Grizzly Bear  Photos  Setlists
# 200538 2020-08-30                                    Matchbox Twenty
# 200539 2020-07-31                                    Matchbox Twenty
# 200735 2022-06-04                       Dave Matthews Band  Setlists
# 200737 2022-06-03                       Dave Matthews Band  Setlists
#
#                                           Venue  \
# 227                            Yaamava' Theater
# 240     Emens Auditorium, Ball State University
# 540                           Starland Ballroom
# 1269                 Chastain Park Amphitheatre
# 1505      Royal Caribbean - Freedom of the Seas
# ...                                         ...
# 200210                           Palace Theatre
# 200538                          Budweiser Stage
# 200539  Veterans United Home Loans Amphitheater
# 200735                       Credit One Stadium
# 200737                       Credit One Stadium
#
#                                                  Location Unnamed: 4  \
# 227     Location    Highland, California, United State...        NaN
# 240                                                   NaN        NaN
# 540     Location    Newark, New Jersey, United States
# ...        NaN
# 1269    Location    Atlanta, Georgia, United States
# Na...        NaN
# 1505                                                  NaN        NaN
# ...                                                   ...        ...
# 200210  Location    Albany, New York, United States
# Na...        NaN
# 200538  Location    Toronto, Ontario, Canada
# Name: Bud...        NaN
# 200539  Location    Virginia Beach, Virginia, United S...        NaN
# 200735  Location    Charleston, South Carolina, United...        NaN
# 200737  Location    Charleston, South Carolina, United...        NaN
#
#                     Artist
# 227           Alice Cooper
# 240           Alice Cooper
# 540                 P.O.D.
# 1269                 Gotye
# 1505             Nightwish
# ...                    ...
# 200210        Grizzly Bear
# 200538     Matchbox Twenty
# 200539     Matchbox Twenty
# 200735  Dave Matthews Band
# 200737  Dave Matthews Band
#
# [643 rows x 6 columns]

# %%
# Remove rows where location is still null
na_loc_still_mask = clean_df["Location"].isna()
clean_df = clean_df[~na_loc_still_mask]
clean_df
# Out:
#              Date                                            Concert  \
# 0      2022-11-26                                          Faithless
# 1      2022-09-24        Faithless / Crazy P / Don Letts / Dat Brass
# 2      2022-09-15                                          faithless
# 3      2022-08-21  Camp Bestival "Camp Bestival" / Rag N Bone Man...
# 4      2022-07-29  Camp Bestival "Camp Bestival" / Rag N Bone Man...
# ...           ...                                                ...
# 200733 2022-06-06                       Dave Matthews Band  Setlists
# 200734 2022-06-06                                 Dave Matthews Band
# 200735 2022-06-04                       Dave Matthews Band  Setlists
# 200736 2022-06-03                       Dave Matthews Band  Setlists
# 200737 2022-06-03                       Dave Matthews Band  Setlists
#
#                         Venue  \
# 0                  Concorde 2
# 1           Dreamland Margate
# 2       Sportpaleis Antwerpen
# 3                 Weston Park
# 4             Lulworth Castle
# ...                       ...
# 200733          Daily's Place
# 200734   Blossom Music Center
# 200735     Credit One Stadium
# 200736     Credit One Stadium
# 200737     Credit One Stadium
#
#                                                  Location Unnamed: 4  \
# 0                       Brighton, England, United Kingdom        NaN
# 1                                 Margate, United Kingdom        NaN
# 2                              Antwerp, Flanders, Belgium        NaN
# 3                                       Staffordshire, UK        NaN
# 4                                  Dorset, United Kingdom        NaN
# ...                                                   ...        ...
# 200733               Jacksonville, Florida, United States        NaN
# 200734                             Cuyahoga Falls, OH, US        NaN
# 200735  Location    Charleston, South Carolina, United...        NaN
# 200736          Charleston, South Carolina, United States        NaN
# 200737  Location    Charleston, South Carolina, United...        NaN
#
#                     Artist
# 0                Faithless
# 1                Faithless
# 2                Faithless
# 3                Faithless
# 4                Faithless
# ...                    ...
# 200733  Dave Matthews Band
# 200734  Dave Matthews Band
# 200735  Dave Matthews Band
# 200736  Dave Matthews Band
# 200737  Dave Matthews Band
#
# [155286 rows x 6 columns]

# %%
# Drop column Unnamed: 4
clean_df = clean_df.drop(["Unnamed: 4"], axis = 1)
clean_df
# Out:
#              Date                                            Concert  \
# 0      2022-11-26                                          Faithless
# 1      2022-09-24        Faithless / Crazy P / Don Letts / Dat Brass
# 2      2022-09-15                                          faithless
# 3      2022-08-21  Camp Bestival "Camp Bestival" / Rag N Bone Man...
# 4      2022-07-29  Camp Bestival "Camp Bestival" / Rag N Bone Man...
# ...           ...                                                ...
# 200733 2022-06-06                       Dave Matthews Band  Setlists
# 200734 2022-06-06                                 Dave Matthews Band
# 200735 2022-06-04                       Dave Matthews Band  Setlists
# 200736 2022-06-03                       Dave Matthews Band  Setlists
# 200737 2022-06-03                       Dave Matthews Band  Setlists
#
#                         Venue  \
# 0                  Concorde 2
# 1           Dreamland Margate
# 2       Sportpaleis Antwerpen
# 3                 Weston Park
# 4             Lulworth Castle
# ...                       ...
# 200733          Daily's Place
# 200734   Blossom Music Center
# 200735     Credit One Stadium
# 200736     Credit One Stadium
# 200737     Credit One Stadium
#
#                                                  Location              Artist
# 0                       Brighton, England, United Kingdom           Faithless
# 1                                 Margate, United Kingdom           Faithless
# 2                              Antwerp, Flanders, Belgium           Faithless
# 3                                       Staffordshire, UK           Faithless
# 4                                  Dorset, United Kingdom           Faithless
# ...                                                   ...                 ...
# 200733               Jacksonville, Florida, United States  Dave Matthews Band
# 200734                             Cuyahoga Falls, OH, US  Dave Matthews Band
# 200735  Location    Charleston, South Carolina, United...  Dave Matthews Band
# 200736          Charleston, South Carolina, United States  Dave Matthews Band
# 200737  Location    Charleston, South Carolina, United...  Dave Matthews Band
#
# [155286 rows x 5 columns]

# %%
# Correct future dates by substracting a century
def replace_future_date(row):
    if not row["Date"] >= pd.Timestamp.today():
        return row["Date"]
    else:
        return row["Date"] - pd.DateOffset(years=100)
    
clean_df["Date"] = clean_df.apply(replace_future_date, axis = 1)
clean_df[clean_df["Date"] > pd.Timestamp.today()]
# Out:
# Empty DataFrame
# Columns: [Date, Concert, Venue, Location, Artist]
# Index: []

# %%
# Check if there are any artists that play concert on the same date
group_df = clean_df.groupby(["Date", "Artist"]).nth(0)
group_df.reset_index()
clean_df = group_df
# Out:
#                                                                           Concert  \
# Date       Artist
# 1951-01-26 Édith Piaf                                                  Édith Piaf
# 1951-01-27 Édith Piaf                                                  Édith Piaf
# 1951-02-20 Édith Piaf                                                  Édith Piaf
# 1952-09-26 Sarah Vaughan        Nat King Cole / Stan Kenton / Sarah Vaughan / ...
# 1956-02-23 Brenda Lee                                      Brenda Lee / Red Foley
# ...                                                                           ...
# 2023-02-24 Theory of a Deadman       Theory of a Deadman / Skillet / Saint Asonia
#            Vance Joy                                                    Vance Joy
#            Willie Nelson                                            Willie Nelson
#            Yo La Tengo                                                Yo La Tengo
#            Zebrahead                                        25 Jahre Tour  Photos
#
#                                                            Venue  \
# Date       Artist
# 1951-01-26 Édith Piaf                               Cinéma Acora
# 1951-01-27 Édith Piaf                             Opéra de Lille
# 1951-02-20 Édith Piaf                                   Alhambra
# 1952-09-26 Sarah Vaughan              William B. Bell Auditorium
# 1956-02-23 Brenda Lee                 William B. Bell Auditorium
# ...                                                          ...
# 2023-02-24 Theory of a Deadman  Allentown Fairgrounds Grandstand
#            Vance Joy                    Jack Singer Concert Hall
#            Willie Nelson          The St. Augustine Amphitheatre
#            Yo La Tengo                              The Fillmore
#            Zebrahead                            Astra Kulturhaus
#
#                                                                 Location
# Date       Artist
# 1951-01-26 Édith Piaf                Brussels, Brussels Capital, Belgium
# 1951-01-27 Édith Piaf                     Lille, Hauts-de-France, France
# 1951-02-20 Édith Piaf                                   Bordeaux, France
# 1952-09-26 Sarah Vaughan                 Augusta, Georgia, United States
# 1956-02-23 Brenda Lee                    Augusta, Georgia, United States
# ...                                                                  ...
# 2023-02-24 Theory of a Deadman    Allentown, Pennsylvania, United States
#            Vance Joy                            Calgary, Alberta, Canada
#            Willie Nelson           St. Augustine, Florida, United States
#            Yo La Tengo          San Francisco, California, United States
#            Zebrahead                             Berlin, Berlin, Germany
#
# [87301 rows x 3 columns]

# %%
# Remove non-ASCII character records
artist_mask = clean_df["Artist"].str.contains(r'[^\x00-\x7F]+')
clean_df["Artist"][artist_mask].drop_duplicates()
# Out:
# 28318             Blue Öyster Cult
# 37719                  Mötley Crüe
# 45038             Jane’s Addiction
# 49956                 Télépopmusik
# 70378             Eagle‐Eye Cherry
# 76324                      Hard‐Fi
# 84871                    Anti‐Flag
# 85394         Bone Thugs‐n‐Harmony
# 95200                    The B‐52s
# 97692                     CHVRCHΞS
# 99976                Róisín Murphy
# 107089         Sophie Ellis‐Bextor
# 109974              Antonín Dvořák
# 109980                  Édith Piaf
# 111954             At the Drive‐In
# 113042         “Weird Al” Yankovic
# 122461               Janelle Monáe
# 129966                     Beyoncé
# 134896                   blink‐182
# 164823    The All‐American Rejects
# 171098               Michael Bublé
# 172113             Destiny’s Child
# 181642                      Tiësto
# 187669                   Motörhead
# Name: Artist, dtype: object

# %%
clean_df.to_csv("cleaned_concert_data.csv")
